# %% [markdown]
# ### Análisis preliminar de los datos

# %%
# Importaciones
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
# Leer el archivo, elimino la columna “Unnamed: 0” generada automáticamente por pandas con index_col
df_raw = pd.read_csv("../data_raw/bank-additional.csv", index_col=0)
df_raw.head()
# Out:
#     age        job  marital    education  default  housing  loan    contact  \
# 0   NaN  housemaid  MARRIED     basic.4y      0.0      0.0   0.0  telephone
# 1  57.0   services  MARRIED  high.school      NaN      0.0   0.0  telephone
# 2  37.0   services  MARRIED  high.school      0.0      1.0   0.0  telephone
# 3  40.0     admin.  MARRIED     basic.6y      0.0      0.0   0.0  telephone
# 4  56.0   services  MARRIED  high.school      0.0      0.0   1.0  telephone
#
#    duration  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0       261         1    999         0  NONEXISTENT           1.1
# 1       149         1    999         0  NONEXISTENT           1.1
# 2       226         1    999         0  NONEXISTENT           1.1
# 3       151         1    999         0  NONEXISTENT           1.1
# 4       307         1    999         0  NONEXISTENT           1.1
#
#   cons.price.idx cons.conf.idx euribor3m nr.employed   y                date  \
# ...

# %%
df_raw.shape
# Out:
# (43000, 23)

# %%
print (f'El número de filas del conjunto de datos es : {df_raw.shape[0]}')
print (f'El número de columnas del conjunto de datos es : {df_raw.shape[1]}')
# Out:
# El número de filas del conjunto de datos es : 43000
# El número de columnas del conjunto de datos es : 23

# %%
df_raw.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'duration', 'campaign', 'pdays', 'previous', 'poutcome',
#        'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m',
#        'nr.employed', 'y', 'date', 'latitude', 'longitude', 'id_'],
#       dtype='object')

# %%
df_raw.sample()
# Out:
#         age          job marital education  default  housing  loan   contact  \
# 15067  27.0  blue-collar  SINGLE  basic.9y      0.0      1.0   0.0  cellular
#
#        duration  campaign  pdays  previous     poutcome  emp.var.rate  \
# 15067       818         1    999         0  NONEXISTENT           1.4
#
#       cons.price.idx cons.conf.idx euribor3m nr.employed   y            date  \
# 15067         93,918         -42,7     4,958      5228,1  no  2-febrero-2018
#
#        latitude  longitude                                   id_
# 15067    45.259    -81.721  ba495ec7-be2b-4cc4-8425-4627174d3e9d

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43000 entries, 0 to 27570
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             37880 non-null  float64
#  1   job             42655 non-null  object
#  2   marital         42915 non-null  object
#  3   education       41193 non-null  object
#  4   default         34019 non-null  float64
#  5   housing         41974 non-null  float64
#  6   loan            41974 non-null  float64
#  7   contact         43000 non-null  object
#  8   duration        43000 non-null  int64
#  9   campaign        43000 non-null  int64
#  10  pdays           43000 non-null  int64
#  11  previous        43000 non-null  int64
#  12  poutcome        43000 non-null  object
#  13  emp.var.rate    43000 non-null  float64
#  14  cons.price.idx  42529 non-null  object
#  15  cons.conf.idx   43000 non-null  object
#  16  euribor3m       33744 non-null  object
# ...

# %%
# Crear un dataframe alternativo para trabajar
df = df_raw.copy()

# %%
df.sample(3)
# Out:
#         age            job  marital          education  default  housing  \
# 14177  30.0    blue-collar  MARRIED        high.school      NaN      1.0
# 32474  34.0         admin.  MARRIED        high.school      NaN      0.0
# 29658  47.0  self-employed  MARRIED  university.degree      0.0      0.0
#
#        loan   contact  duration  campaign  pdays  previous     poutcome  \
# 14177   0.0  cellular      1153         3    999         0  NONEXISTENT
# 32474   0.0  cellular       267         2    999         0  NONEXISTENT
# 29658   0.0  cellular       145         1    999         0  NONEXISTENT
#
#        emp.var.rate cons.price.idx cons.conf.idx euribor3m nr.employed    y  \
# 14177           1.4         93,918         -42,7       NaN      5228,1  yes
# 32474          -1.8         92,893         -46,2     1,313      5099,1   no
# 29658          -1.8         93,075         -47,1     1,405      5099,1   no
#
#                  date  latitude  longitude  \
# ...

# %%
# Guardo archivo
df.to_csv("../data_processed/ba_transformacion.csv", index=False)
