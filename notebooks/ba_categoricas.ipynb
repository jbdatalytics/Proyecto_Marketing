# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('..')

import matplotlib.pyplot as plt
import seaborn as sns

from src import sp_eda, sp_visualizacion as vis

# %%
df_clean= pd.read_csv('../data_processed/ba_limpieza.csv', parse_dates=['Date'])
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             37880 non-null  float64
#  1   Job             42655 non-null  object
#  2   Marital         42915 non-null  object
#  3   Education       41193 non-null  object
#  4   Default         34019 non-null  object
#  5   Housing         41974 non-null  object
#  6   Loan            41974 non-null  object
#  7   Contact         43000 non-null  object
#  8   Duration        43000 non-null  int64
#  9   Campaign        43000 non-null  int64
#  10  Pdays           43000 non-null  int64
#  11  Previous        43000 non-null  int64
#  12  Poutcome        43000 non-null  object
#  13  Emp.Var.Rate    43000 non-null  float64
#  14  Cons.Price.Idx  42529 non-null  float64
#  15  Cons.Conf.Idx   43000 non-null  float64
#  16  Euribor3M       33744 non-null  float64
# ...

# %%
# Análisis y gestión de nulos de las columnas categóricas

numero_nulos_df_clean, porcentaje_nulos_df_clean= sp_eda.calcular_nulos(df_clean)

# %%
porcentaje_nulos_df_clean
# Out:
# Age               11.91
# Job                0.80
# Marital            0.20
# Education          4.20
# Default           20.89
# Housing            2.39
# Loan               2.39
# Contact            0.00
# Duration           0.00
# Campaign           0.00
# Pdays              0.00
# Previous           0.00
# Poutcome           0.00
# Emp.Var.Rate       0.00
# Cons.Price.Idx     1.10
# Cons.Conf.Idx      0.00
# Euribor3M         21.53
# Nr.Employed        0.00
# Y                  0.00
# Date               0.58
# Latitude           0.00
# Longitude          0.00
# Id_                0.00
# Year               0.58
# Month              0.58
# Day_Name           0.58
# Quarter            0.58
# dtype: float64

# %%
sp_eda.analisis_col_cat(df_clean)
# Out:
# La distribución de la columna JOB
# Esta columna tiene 12 valores únicos
# Job
# admin.           0.254906
# blue-collar      0.226328
# technician       0.164717
# services         0.097574
# management       0.071504
# retired          0.041965
# entrepreneur     0.035682
# self-employed    0.034908
# housemaid        0.026328
# unemployed       0.024921
# student          0.021170
# Name: proportion, dtype: float64
# --------------------
#  Describe
# count      42655
# unique        11
# top       admin.
# freq       10873
# Name: Job, dtype: object
# --------------------
# La distribución de la columna MARITAL
# Esta columna tiene 4 valores únicos
# Marital
# married     0.605825
# single      0.282069
# divorced    0.112105
# Name: proportion, dtype: float64
# --------------------
#  Describe
# count       42915
# unique          3
# top       married
# freq        25999
# Name: Marital, dtype: object
# --------------------
# La distribución de la columna EDUCATION
# ...

# %%
vis.subplot_col_cat(df_clean)

# %%
df_cat= df_clean[df_clean.select_dtypes(include='O').columns]
df_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Job        42655 non-null  object
#  1   Marital    42915 non-null  object
#  2   Education  41193 non-null  object
#  3   Default    34019 non-null  object
#  4   Housing    41974 non-null  object
#  5   Loan       41974 non-null  object
#  6   Contact    43000 non-null  object
#  7   Poutcome   43000 non-null  object
#  8   Y          43000 non-null  object
#  9   Id_        43000 non-null  object
#  10  Month      42752 non-null  object
#  11  Day_Name   42752 non-null  object
# dtypes: object(12)
# memory usage: 3.9+ MB

# %%
sp_eda.calcular_nulos(df_cat)[1]
# Out:
# Job           0.80
# Marital       0.20
# Education     4.20
# Default      20.89
# Housing       2.39
# Loan          2.39
# Contact       0.00
# Poutcome      0.00
# Y             0.00
# Id_           0.00
# Month         0.58
# Day_Name      0.58
# dtype: float64

# %%
df_cat=df_cat.fillna('unknown')
sp_eda.calcular_nulos(df_cat)[1]
# Out:
# Job          0.0
# Marital      0.0
# Education    0.0
# Default      0.0
# Housing      0.0
# Loan         0.0
# Contact      0.0
# Poutcome     0.0
# Y            0.0
# Id_          0.0
# Month        0.0
# Day_Name     0.0
# dtype: float64

# %%
df_clean[df_clean.select_dtypes(include='O').columns]=df_cat       
sp_eda.calcular_nulos(df_clean)[1]
# Out:
# Age               11.91
# Job                0.00
# Marital            0.00
# Education          0.00
# Default            0.00
# Housing            0.00
# Loan               0.00
# Contact            0.00
# Duration           0.00
# Campaign           0.00
# Pdays              0.00
# Previous           0.00
# Poutcome           0.00
# Emp.Var.Rate       0.00
# Cons.Price.Idx     1.10
# Cons.Conf.Idx      0.00
# Euribor3M         21.53
# Nr.Employed        0.00
# Y                  0.00
# Date               0.58
# Latitude           0.00
# Longitude          0.00
# Id_                0.00
# Year               0.58
# Month              0.00
# Day_Name           0.00
# Quarter            0.58
# dtype: float64

# %%
df_clean.sample(3)
# Out:
#         Age         Job Marital            Education Default Housing Loan  \
# 31823  34.0    services  single          high.school      no     yes  yes
# 36971   NaN  technician  single  professional.course      no     yes   no
# 29170  35.0      admin.  single    university.degree      no     yes   no
#
#         Contact  Duration  Campaign  ...  Nr.Employed   Y       Date  \
# 31823  cellular       269         2  ...       5099.1  no 2016-09-25
# 36971  cellular       251         1  ...       5076.2  no 2019-03-12
# 29170  cellular       334         2  ...       5099.1  no 2019-12-22
#
#        Latitude  Longitude                                   Id_    Year  \
# 31823    36.057    -90.390  e3803439-0bbc-4209-8c28-12a6b154aabf  2016.0
# 36971    44.111    -89.725  d1235ff7-7a34-4977-b8b5-06bc7aac4d9c  2019.0
# 29170    46.161   -102.207  6f4691cf-8013-4a1b-81d6-95e509ae101c  2019.0
#
#            Month Day_Name Quarter
# 31823  september   sunday     3.0
# ...

# %%
df_clean.to_csv("../data_processed/ba_limpieza.csv", index=False)
